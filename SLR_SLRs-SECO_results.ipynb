# %%
# -*- coding: utf-8 -*-
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 20)


import numpy as np

from scipy import stats

from bokeh.io import show, output_file
from bokeh.plotting import figure

 
# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds']
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20b
from bokeh.models import LabelSet
import math

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7b41def1-c411-4521-96b0-c0e2e126bc48">Loading BokehJS ...</span>
#     </div>

# %%
spreadsheet = client.open_by_key("1VVFCmjWpqHSGdpwdLN7pi9ao3pZzsCGhGX-OSevX2q4")
sheetFinalResults = spreadsheet.get_worksheet(2)

# %%
#list_of_hashesA = sheetA1.get_all_records()
#print(list_of_hashes)

data = pd.DataFrame(sheetFinalResults.get_all_records())

print("Number of papers resulting the SLR: ", len(data))
# Out:
# Number of papers resulting the SLR:  13

# %%
display(data.head())
# Out:
#    % similitud   ...MQ9    ..IQ2 ..IQ3    ..MQ1    ..MQ2    ..MQ3    ..MQ4  \
# 0          2.5           Parcial        Parcial  Parcial  Parcial  Parcial
# 1          1.5  Parcial  Parcial
# 2          0.0
# 3          1.5       Sí  Parcial
# 4          0.0
#
#   ..MQ5 ..MQ6                        ...                          Year  \
# 0                                    ...                          2017
# 1                                    ...                          2016
# 2                                    ...                          2016
# 3                                    ...                          2016
# 4                                    ...                          2015
#
#         ¿Cuál es el dominio?  \
# 0          Open Source SECOs
# 1                      SECOs
# 2  Existing propietary SECOs
# 3                      SECOs
# 4               Mobile SECOs
#
#          ¿Cuáles son las preguntas de investigación?  \
# 0  RQ1. What are the demographic characteristics ...
# 1  RQ 1: How has the number of publications evolv...
# 2  No realiza la revisión de la literatura, anali...
# 3  RQ1. What constitutes a Software Ecosystem and...
# 4  RQ1. What are the main characteristics and ben...
#
#   ¿Qué aspecto de los ecosistemas tecnológicos analiza?  \
# 0                       Definiciones y clasificación
# 1  Definiciones, estado de la investigación en el...
# 2                                    Características
# 3                Modelado y definición de soluciones
# 4  Características, estado de la investigación y ...
#
#                         ¿Qué bases de datos utiliza? ¿Qué fechas abarca?  \
# 0  ACM, IEEE, ScienceDirect, SpringerLink, Wiley,...           2003-2015
# 1        ACM, IEEE, ScienceDirect, SpringerLink, WoS           2007-2014
# 2        ACM, IEEE, ScienceDirect, SpringerLink, WoS           2008-2014
# 3                           ACM, IEEE, ScienceDirect           2006-2016
# 4                        Scopus, IEEE, ScienceDirect           2010-2014
#
#   ¿Realiza un mapping? ¿Realiza una revisión de la literatura?  \
# 0                   Sí                                      No
# 1              Parcial                                      Sí
# 2                   No                                      Sí
# 3                   Sí                                      No
# 4                   Sí                                      No
#
#   ¿Responde a la pregunta de investigación IQ1?  \
# 0
# 1                                       Parcial
# 2
# 3
# 4
#
#                               ¿Términos de búsqueda?
# 0  OSS, FOSS, FLOSS, Open Source, Free Software, ...
# 1            software ecosystem, software ecosystems
# 2            software ecosystem, software ecosystems
# 3  software ecosystem, software ecosystems, docum...
# 4  software ecosystem, app, apps, application, ap...
#
# [5 rows x 32 columns]

# %%
keywords = data["¿Términos de búsqueda?"].values
keywords_list = []
for keyword in keywords:
    [keywords_list.append(x.strip()) for x in keyword.split(',')]
    
keywords_list = [x for x in keywords_list if x != '']
display(keywords_list)

dfKeywords = pd.DataFrame(keywords_list)
# Out:
# ['OSS',
#  'FOSS',
#  'FLOSS',
#  'Open Source',
#  'Free Software',
#  'Libre Software',
#  'ecosystem',
#  'Software Supply Network',
#  'Software Supply Industry',
#  'software ecosystem',
#  'software ecosystems',
#  'software ecosystem',
#  'software ecosystems',
#  'software ecosystem',
#  'software ecosystems',
#  'documentation',
#  'model',
#  'modeling',
#  'documenting',
#  'view',
#  'viewpoint',
#  'ISO42010',
#  'software ecosystem',
#  'app',
#  'apps',
#  'application',
#  'applications',
#  'game',
#  'games',
#  'embedded',
#  'mobile',
#  'microsoft',
#  'nokia',
#  'blackberry',
#  'apple',
#  'google',
#  'android',
#  'ios',
#  'windows',
#  'embedded software',
#  'embedded system',
#  'product development',
#  'ecosystem',
#  'eco system',
#  'eco-system',
#  'product-line',
#  'product line',
#  'productline',
#  'open-source',
#  'opensource',
#  'third party',
#  'third-party',
#  'business model',
#  'businessmodel',
#  'business model',
#  'innovation system',
#  'open innovation',
#  'strategic innovation',
#  'software ecosystem',
#  'health',
#  'software ecosystem',
#  'software intensive ecosystem',
#  'digital ecosystem',
#  'mobile ecosystem',
#  'service ecosystem',
#  'cloud ecosystem',
#  'communic* ecosystem',
#  'telecom* ecosystem',
#  'ict ecosystem (todo con supply network)',
#  'measur*',
#  'kpi*',
#  'metric',
#  'analytic',
#  'indicator',
#  'success factor',
#  'quality attribute',
#  'key characteristic',
#  'software ecosystem',
#  'software ecosystems',
#  'software ecosystem',
#  'requirement',
#  'specif*',
#  'model*',
#  'verif*',
#  'valid*',
#  'elicit*',
#  'analy*',
#  'negotiate',
#  'document',
#  'manag*',
#  'non-functional requirement',
#  'software quality',
#  'security',
#  'safety',
#  'usability',
#  'maintainability',
#  'testability',
#  'performance',
#  'reliability',
#  'software ecosystem',
#  'platform ecosystem',
#  'software ecosystem*',
#  'software supply network',
#  'software vendor*',
#  'software supply industry',
#  'advantage*',
#  'reward',
#  'limitation*',
#  'restriction*',
#  'challenge*',
#  'implication*',
#  'significance*',
#  'consequence*',
#  'discipline*',
#  'area*',
#  'subject area',
#  'subject field',
#  'field',
#  'software engineering',
#  'software development',
#  'systems engineering',
#  'characteristic',
#  'attribute',
#  'industry',
#  'marketplace',
#  'market',
#  'activity',
#  'academic community',
#  'software ecosystem']

# %%
display(dfKeywords)
# Out:
#                                            0
# 0                                        OSS
# 1                                       FOSS
# 2                                      FLOSS
# 3                                Open Source
# 4                              Free Software
# 5                             Libre Software
# 6                                  ecosystem
# 7                    Software Supply Network
# 8                   Software Supply Industry
# 9                         software ecosystem
# 10                       software ecosystems
# 11                        software ecosystem
# 12                       software ecosystems
# 13                        software ecosystem
# 14                       software ecosystems
# 15                             documentation
# 16                                     model
# 17                                  modeling
# 18                               documenting
# 19                                      view
# 20                                 viewpoint
# 21                                  ISO42010
# 22                        software ecosystem
# 23                                       app
# 24                                      apps
# 25                               application
# 26                              applications
# 27                                      game
# 28                                     games
# 29                                  embedded
# 30                                    mobile
# 31                                 microsoft
# 32                                     nokia
# 33                                blackberry
# 34                                     apple
# 35                                    google
# 36                                   android
# 37                                       ios
# 38                                   windows
# 39                         embedded software
# 40                           embedded system
# 41                       product development
# 42                                 ecosystem
# 43                                eco system
# 44                                eco-system
# 45                              product-line
# 46                              product line
# 47                               productline
# 48                               open-source
# 49                                opensource
# 50                               third party
# 51                               third-party
# 52                            business model
# 53                             businessmodel
# 54                            business model
# 55                         innovation system
# 56                           open innovation
# 57                      strategic innovation
# 58                        software ecosystem
# 59                                    health
# 60                        software ecosystem
# 61              software intensive ecosystem
# 62                         digital ecosystem
# 63                          mobile ecosystem
# 64                         service ecosystem
# 65                           cloud ecosystem
# 66                       communic* ecosystem
# 67                        telecom* ecosystem
# 68   ict ecosystem (todo con supply network)
# 69                                   measur*
# 70                                      kpi*
# 71                                    metric
# 72                                  analytic
# 73                                 indicator
# 74                            success factor
# 75                         quality attribute
# 76                        key characteristic
# 77                        software ecosystem
# 78                       software ecosystems
# 79                        software ecosystem
# 80                               requirement
# 81                                   specif*
# 82                                    model*
# 83                                    verif*
# 84                                    valid*
# 85                                   elicit*
# 86                                    analy*
# 87                                 negotiate
# 88                                  document
# 89                                    manag*
# 90                non-functional requirement
# 91                          software quality
# 92                                  security
# 93                                    safety
# 94                                 usability
# 95                           maintainability
# 96                               testability
# 97                               performance
# 98                               reliability
# 99                        software ecosystem
# 100                       platform ecosystem
# 101                      software ecosystem*
# 102                  software supply network
# 103                         software vendor*
# 104                 software supply industry
# 105                               advantage*
# 106                                   reward
# 107                              limitation*
# 108                             restriction*
# 109                               challenge*
# 110                             implication*
# 111                            significance*
# 112                             consequence*
# 113                              discipline*
# 114                                    area*
# 115                             subject area
# 116                            subject field
# 117                                    field
# 118                     software engineering
# 119                     software development
# 120                      systems engineering
# 121                           characteristic
# 122                                attribute
# 123                                 industry
# 124                              marketplace
# 125                                   market
# 126                                 activity
# 127                       academic community
# 128                       software ecosystem

# %%
dfKeywords.columns = ['Term']
#dfKeywords.groupby('Term').count()
resultsKeywords = pd.DataFrame(dfKeywords['Term'].value_counts())
resultsKeywords.reset_index(level=0, inplace=True)
resultsKeywords.columns = ['Term', 'Count']

resultsKeywords.sort_values(['Count', 'Term'], ascending=[False, True], inplace=True)
display(resultsKeywords)
# Out:
#                                         Term  Count
# 0                         software ecosystem     10
# 1                        software ecosystems      4
# 2                             business model      2
# 3                                  ecosystem      2
# 33                                     FLOSS      1
# 19                                      FOSS      1
# 13                             Free Software      1
# 12                                  ISO42010      1
# 112                           Libre Software      1
# 48                                       OSS      1
# 105                              Open Source      1
# 100                 Software Supply Industry      1
# 67                   Software Supply Network      1
# 86                        academic community      1
# 75                                  activity      1
# 27                                advantage*      1
# 89                                    analy*      1
# 101                                 analytic      1
# 46                                   android      1
# 71                                       app      1
# 9                                      apple      1
# 14                               application      1
# 18                              applications      1
# 15                                      apps      1
# 81                                     area*      1
# 36                                 attribute      1
# 30                                blackberry      1
# 37                             businessmodel      1
# 4                                 challenge*      1
# 28                            characteristic      1
# 38                           cloud ecosystem      1
# 73                       communic* ecosystem      1
# 5                               consequence*      1
# 6                          digital ecosystem      1
# 22                               discipline*      1
# 88                                  document      1
# 25                             documentation      1
# 39                               documenting      1
# 59                                eco system      1
# 95                                eco-system      1
# 62                                   elicit*      1
# 114                                 embedded      1
# 76                         embedded software      1
# 52                           embedded system      1
# 107                                    field      1
# 56                                      game      1
# 32                                     games      1
# 61                                    google      1
# 34                                    health      1
# 98   ict ecosystem (todo con supply network)      1
# 16                              implication*      1
# 109                                indicator      1
# 45                                  industry      1
# 99                         innovation system      1
# 106                                      ios      1
# 23                        key characteristic      1
# 87                                      kpi*      1
# 21                               limitation*      1
# 63                           maintainability      1
# 53                                    manag*      1
# 40                                    market      1
# 78                               marketplace      1
# 90                                   measur*      1
# 84                                    metric      1
# 108                                microsoft      1
# 11                                    mobile      1
# 69                          mobile ecosystem      1
# 17                                     model      1
# 24                                    model*      1
# 65                                  modeling      1
# 72                                 negotiate      1
# 29                                     nokia      1
# 42                non-functional requirement      1
# 70                           open innovation      1
# 35                               open-source      1
# 92                                opensource      1
# 96                               performance      1
# 51                        platform ecosystem      1
# 55                       product development      1
# 113                             product line      1
# 26                              product-line      1
# 77                               productline      1
# 60                         quality attribute      1
# 102                              reliability      1
# 57                               requirement      1
# 54                              restriction*      1
# 74                                    reward      1
# 80                                    safety      1
# 104                                 security      1
# 66                         service ecosystem      1
# 43                             significance*      1
# 68                      software development      1
# 91                       software ecosystem*      1
# 111                     software engineering      1
# 85              software intensive ecosystem      1
# 64                          software quality      1
# 49                  software supply industry      1
# 8                    software supply network      1
# 79                          software vendor*      1
# 97                                   specif*      1
# 83                      strategic innovation      1
# 20                              subject area      1
# 50                             subject field      1
# 103                           success factor      1
# 94                       systems engineering      1
# 82                        telecom* ecosystem      1
# 58                               testability      1
# 7                                third party      1
# 44                               third-party      1
# 110                                usability      1
# 41                                    valid*      1
# 47                                    verif*      1
# 31                                      view      1
# 93                                 viewpoint      1
# 10                                   windows      1

# %%
# output_file('vbar.html')

p = figure(x_range=resultsKeywords['Term'].tolist(), plot_width=1250, toolbar_location=None, title="Keywords Counts")
p.vbar(x=resultsKeywords['Term'].tolist(), top=resultsKeywords['Count'].tolist(), width=0.3)
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 10
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bb29162a-d40d-4fdc-9327-86760b6f3cec"></div>
# </div>

# %%
authors = data["Authors"].values
authors_list = []
for author in authors:
    [authors_list.append(x.strip()) for x in author.split(';')]
    
authors_list = [x for x in authors_list if x != '']
# display(authors_list)

dfAuthors = pd.DataFrame(authors_list)
dfAuthors.columns = ['Name']
display(dfAuthors)
# Out:
#                   Name
# 0     Franco-Bedoya, O
# 1           Ameller, D
# 2            Costal, D
# 3            Franch, X
# 4           Manikas, K
# 5           Manikas, K
# 6        Pettersson, O
# 7         Andersson, J
# 8           Fontao, AD
# 9       dos Santos, RP
# 10       Dias-Neto, AC
# 11  Papatheocharous, E
# 12        Andersson, J
# 13         Axelsson, J
# 14       Hyrynsalmi, S
# 15         Seppanen, M
# 16          Nokkala, T
# 17         Suominen, A
# 18            Jarvi, A
# 19         Fotrousi, F
# 20         Fricker, SA
# 21          Fiedler, M
# 22          Le-Gall, F
# 23          Manikas, K
# 24          Hansen, KM
# 25        Vegendla, A.
# 26           Duc, A.N.
# 27             Gao, S.
# 28          Sindre, G.
# 29           Alves, C.
# 30        Oliveira, J.
# 31          Jansen, S.
# 32         Barbosa, O.
# 33           Alves, C.
# 34         Hanssen, G.
# 35            Dybå, T.

# %%
resultsAuthors = pd.DataFrame(dfAuthors['Name'].value_counts())
# display(resultsAuthors)
resultsAuthors.reset_index(level=0, inplace=True)
resultsAuthors.columns = ['Name', 'Count']

resultsAuthors.sort_values(['Count', 'Name'], ascending=[False, True], inplace=True)
display(resultsAuthors)
# Out:
#                   Name  Count
# 0           Manikas, K      3
# 2            Alves, C.      2
# 1         Andersson, J      2
# 28          Ameller, D      1
# 16         Axelsson, J      1
# 8          Barbosa, O.      1
# 14           Costal, D      1
# 26       Dias-Neto, AC      1
# 27           Duc, A.N.      1
# 5             Dybå, T.      1
# 18          Fiedler, M      1
# 22          Fontao, AD      1
# 13         Fotrousi, F      1
# 24           Franch, X      1
# 20    Franco-Bedoya, O      1
# 21         Fricker, SA      1
# 10             Gao, S.      1
# 17          Hansen, KM      1
# 4          Hanssen, G.      1
# 29       Hyrynsalmi, S      1
# 30          Jansen, S.      1
# 11            Jarvi, A      1
# 31          Le-Gall, F      1
# 23          Nokkala, T      1
# 6         Oliveira, J.      1
# 7   Papatheocharous, E      1
# 9        Pettersson, O      1
# 15         Seppanen, M      1
# 12          Sindre, G.      1
# 19         Suominen, A      1
# 25        Vegendla, A.      1
# 3       dos Santos, RP      1

# %%
p = figure(x_range=resultsAuthors['Name'].tolist(), plot_width=1250, toolbar_location=None, title="Authors Counts")
p.vbar(x=resultsAuthors['Name'].tolist(), top=resultsAuthors['Count'].tolist(), width=0.3)
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 4
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a0d98866-cd7d-483b-bc4f-9fa815b0b6d5"></div>
# </div>

# %%
resultsYears = pd.DataFrame(data['Year'].value_counts())
resultsYears.reset_index(level=0, inplace=True)
resultsYears.columns = ['Year', 'Count']
resultsYears.sort_values(['Year', 'Count'], ascending=[False, False], inplace=True)
display(resultsYears)
# Out:
#    Year  Count
# 7  2018      1
# 2  2017      2
# 1  2016      3
# 0  2015      3
# 3  2014      1
# 4  2013      1
# 5  2012      1
# 6  2011      1

# %%
p = figure(x_range=resultsYears['Year'].astype('str').tolist(), plot_width=600, title="Papers per year")
p.vbar(x=resultsYears['Year'].astype('str').tolist(), top=resultsYears['Count'].astype('int').tolist(), width=0.9)
p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="05e2e205-517c-4a0d-bf8f-bc9a867cd1ab"></div>
# </div>

# %%
resultsType = pd.DataFrame(data['Type of publication (Journal, Book, Conference proceedings, etc)'].value_counts())
resultsType.reset_index(level=0, inplace=True)
resultsType.columns = ['Type', 'Count']
resultsType.sort_values(['Type', 'Count'], ascending=[False, False], inplace=True)
display(resultsType)
# Out:
#                Type  Count
# 2            Review      1
# 0  Conference Paper      9
# 1           Article      3

# %%
p = figure(x_range=resultsType['Type'].tolist(), title="Publication type")
p.vbar(x=resultsType['Type'].tolist(), top=resultsType['Count'].tolist(), width=0.9)
p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="11c8b7d5-32f2-40ec-9db0-ceb5ba77c263"></div>
# </div>

# %%
sources = data["¿Qué bases de datos utiliza?"].values
sources_list = []
for source in sources:
    [sources_list.append(x.strip()) for x in source.split(',')]
    
sources_list = [x for x in sources_list if x != '']
display(sources_list)

dfSources = pd.DataFrame(sources_list)
# Out:
# ['ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'Wiley',
#  'Engineering Village',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'WoS',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'WoS',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'Scopus',
#  'IEEE',
#  'ScienceDirect',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'Engineering Village',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'WoS',
#  'Proquest',
#  'Wiley',
#  'Scopus',
#  'Inspect',
#  'Engineering Village',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'WoS',
#  'Scopus',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'SpringerLink',
#  'Scopus',
#  'ACM',
#  'IEEE',
#  'ScienceDirect',
#  'Engineering Village',
#  'WoS',
#  'WoS']

# %%
display(dfSources)
# Out:
#                       0
# 0                   ACM
# 1                  IEEE
# 2         ScienceDirect
# 3          SpringerLink
# 4                 Wiley
# 5   Engineering Village
# 6                   ACM
# 7                  IEEE
# 8         ScienceDirect
# 9          SpringerLink
# 10                  WoS
# 11                  ACM
# 12                 IEEE
# 13        ScienceDirect
# 14         SpringerLink
# 15                  WoS
# 16                  ACM
# 17                 IEEE
# 18        ScienceDirect
# 19               Scopus
# 20                 IEEE
# 21        ScienceDirect
# 22                  ACM
# 23                 IEEE
# 24        ScienceDirect
# 25         SpringerLink
# 26  Engineering Village
# 27                  ACM
# 28                 IEEE
# 29        ScienceDirect
# 30         SpringerLink
# 31                  WoS
# 32             Proquest
# 33                Wiley
# 34               Scopus
# 35              Inspect
# 36  Engineering Village
# 37                  ACM
# 38                 IEEE
# 39        ScienceDirect
# 40         SpringerLink
# 41                  WoS
# 42               Scopus
# 43                  ACM
# 44                 IEEE
# 45        ScienceDirect
# 46                  ACM
# 47                 IEEE
# 48        ScienceDirect
# 49         SpringerLink
# 50               Scopus
# 51                  ACM
# 52                 IEEE
# 53        ScienceDirect
# 54  Engineering Village
# 55                  WoS
# 56                  WoS

# %%
dfSources.columns = ['Source']
#dfSources.groupby('Source').count()
resultsSources = pd.DataFrame(dfSources['Source'].value_counts())
resultsSources.reset_index(level=0, inplace=True)
resultsSources.columns = ['Source', 'Count']
display(resultsSources)
# Out:
#                 Source  Count
# 0                 IEEE     11
# 1        ScienceDirect     11
# 2                  ACM     10
# 3         SpringerLink      7
# 4                  WoS      6
# 5               Scopus      4
# 6  Engineering Village      4
# 7                Wiley      2
# 8              Inspect      1
# 9             Proquest      1

# %%
# output_file('vbar.html')

p = figure(x_range=resultsSources['Source'].tolist(), title="Source Counts")
p.vbar(x=resultsSources['Source'].tolist(), top=resultsSources['Count'].tolist(), width=0.6)
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 11
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="84ceedf7-05eb-491e-9a98-d435f5723c48"></div>
# </div>
